# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('KAts.csv', low_memory = False, parse_dates = ['Date'])

# %%
df.head()
# Out:
#    Case Age     Sex    Date X09.03.2020 X10.03.2020 X11.03.2020 X12.03.2020  \
# 0     1  41    Male  09-Mar           H           H           H           H
# 1     2   0  Female  10-Mar         NaN           H           H           H
# 2     3  13  Female  10-Mar         NaN           H           H           H
# 3     4   0     NaN  09-Mar           H           H           H           H
# 4     5  26    Male  13-Mar         NaN         NaN         NaN         NaN
#
#   X13.03.2020 X14.03.2020  ... X03.07.2020 X04.07.2020 X05.07.2020  \
# 0           H           H  ...           C           C           C
# 1           H           H  ...           C           C           C
# 2           H           H  ...           C           C           C
# 3           H           H  ...           C           C           C
# 4           H           H  ...           C           C           C
#
#   X06.07.2020 X07.07.2020 X08.07.2020 X09.07.2020 X10.07.2020 X11.07.2020  \
# ...

# %%
# Converting the "Date" column to datetime format
df['Date']=pd.to_datetime(df['Date'].apply(lambda x: x+'-2020'))

# %% [markdown]
# # Removing "X" from column names

# %%
col = pd.Series(df.columns[4:])

def remove_X(x):
    return pd.to_datetime(x[1:], dayfirst=True)

c = col.apply(lambda x: remove_X(x))
c.index = range(len(df.columns))[4:]
c  # "c" will hold the new column names
# Out:
# 4     2020-03-09
# 5     2020-03-10
# 6     2020-03-11
# 7     2020-03-12
# 8     2020-03-13
#          ...
# 125   2020-07-08
# 126   2020-07-09
# 127   2020-07-10
# 128   2020-07-11
# 129   2020-07-12
# Length: 126, dtype: datetime64[ns]

# %%
# Appending the first four columns to "c"
c[0]=df.columns[0]
c[1]=df.columns[1]
c[2] = df.columns[2]
c[3] =df.columns[3]

# Sorting the series as per index
c.sort_index(inplace = True)

# Renaming columns
df.columns = c

del c

# %%
df['Date'][0] == df.columns[4]
# Out:
# True

# %%
df.Case.is_monotonic
# Out:
# True

# %%
df.set_index('Case', inplace=True)
df.head()
# Out:
#      Age     Sex       Date 2020-03-09 00:00:00 2020-03-10 00:00:00  \
# Case
# 1     41    Male 2020-03-09                   H                   H
# 2      0  Female 2020-03-10                 NaN                   H
# 3     13  Female 2020-03-10                 NaN                   H
# 4      0     NaN 2020-03-09                   H                   H
# 5     26    Male 2020-03-13                 NaN                 NaN
#
#      2020-03-11 00:00:00 2020-03-12 00:00:00 2020-03-13 00:00:00  \
# Case
# 1                      H                   H                   H
# 2                      H                   H                   H
# 3                      H                   H                   H
# 4                      H                   H                   H
# 5                    NaN                 NaN                   H
#
#      2020-03-14 00:00:00 2020-03-15 00:00:00  ... 2020-07-03 00:00:00  \
# Case                                          ...
# ...

# %% [markdown]
# # Hospitalised
#
# ## Don't need to do this, simply use the index

# %%
# This results in a dataframe with "True" in the cells where "H" was present

df1 = df.isin(['H']).copy()

df1.shape
# Out:
# (38843, 129)

# %%
 df1.head()
# Out:
#         Age    Sex   Date  2020-03-09 00:00:00  2020-03-10 00:00:00  \
# Case
# 1     False  False  False                 True                 True
# 2     False  False  False                False                 True
# 3     False  False  False                False                 True
# 4     False  False  False                 True                 True
# 5     False  False  False                False                False
#
#       2020-03-11 00:00:00  2020-03-12 00:00:00  2020-03-13 00:00:00  \
# Case
# 1                    True                 True                 True
# 2                    True                 True                 True
# 3                    True                 True                 True
# 4                    True                 True                 True
# 5                   False                False                 True
#
#       2020-03-14 00:00:00  2020-03-15 00:00:00  ...  2020-07-03 00:00:00  \
# Case                                            ...
# ...

# %%
# This converts the "True" to "1.0" and "False" to "NaN"
df1 = df1[df1==True]

df1.shape
# Out:
# (38843, 129)

# %%
df1.head()
# Out:
#       Age  Sex  Date  2020-03-09 00:00:00  2020-03-10 00:00:00  \
# Case
# 1     NaN  NaN   NaN                  1.0                  1.0
# 2     NaN  NaN   NaN                  NaN                  1.0
# 3     NaN  NaN   NaN                  NaN                  1.0
# 4     NaN  NaN   NaN                  1.0                  1.0
# 5     NaN  NaN   NaN                  NaN                  NaN
#
#       2020-03-11 00:00:00  2020-03-12 00:00:00  2020-03-13 00:00:00  \
# Case
# 1                     1.0                  1.0                  1.0
# 2                     1.0                  1.0                  1.0
# 3                     1.0                  1.0                  1.0
# 4                     1.0                  1.0                  1.0
# 5                     NaN                  NaN                  1.0
#
#       2020-03-14 00:00:00  2020-03-15 00:00:00  ...  2020-07-03 00:00:00  \
# Case                                            ...
# ...

# %%
# Dropping rows where all values are "NaN"
df1.dropna(axis=0, how='all', inplace=True)
df1.shape
# Out:
# (1123, 129)

# %%
df1.idxmax(axis=1)
# Out:
# Case
# 1      2020-03-09
# 2      2020-03-10
# 3      2020-03-10
# 4      2020-03-09
# 5      2020-03-13
#           ...
# 1143   2020-05-17
# 1144   2020-05-17
# 1145   2020-05-17
# 1146   2020-05-17
# 1147   2020-05-17
# Length: 1123, dtype: datetime64[ns]

# %%
df1.tail()
# Out:
#       Age  Sex  Date  2020-03-09 00:00:00  2020-03-10 00:00:00  \
# Case
# 1143  NaN  NaN   NaN                  NaN                  NaN
# 1144  NaN  NaN   NaN                  NaN                  NaN
# 1145  NaN  NaN   NaN                  NaN                  NaN
# 1146  NaN  NaN   NaN                  NaN                  NaN
# 1147  NaN  NaN   NaN                  NaN                  NaN
#
#       2020-03-11 00:00:00  2020-03-12 00:00:00  2020-03-13 00:00:00  \
# Case
# 1143                  NaN                  NaN                  NaN
# 1144                  NaN                  NaN                  NaN
# 1145                  NaN                  NaN                  NaN
# 1146                  NaN                  NaN                  NaN
# 1147                  NaN                  NaN                  NaN
#
#       2020-03-14 00:00:00  2020-03-15 00:00:00  ...  2020-07-03 00:00:00  \
# Case                                            ...
# ...

# %%
del df1

# %% [markdown]
# # Cured

# %%
df2 = df.isin(['C']).copy()

# %%
df2 = df2[df2==True]
df2.dropna(axis=0,how='all', inplace=True)
temp = df2.idxmax(axis=1)

# %%
df2.head()
# Out:
#       Age  Sex  Date  2020-03-09 00:00:00  2020-03-10 00:00:00  \
# Case
# 1     NaN  NaN   NaN                  NaN                  NaN
# 2     NaN  NaN   NaN                  NaN                  NaN
# 3     NaN  NaN   NaN                  NaN                  NaN
# 4     NaN  NaN   NaN                  NaN                  NaN
# 5     NaN  NaN   NaN                  NaN                  NaN
#
#       2020-03-11 00:00:00  2020-03-12 00:00:00  2020-03-13 00:00:00  \
# Case
# 1                     NaN                  NaN                  NaN
# 2                     NaN                  NaN                  NaN
# 3                     NaN                  NaN                  NaN
# 4                     NaN                  NaN                  NaN
# 5                     NaN                  NaN                  NaN
#
#       2020-03-14 00:00:00  2020-03-15 00:00:00  ...  2020-07-03 00:00:00  \
# Case                                            ...
# ...

# %%
df2.shape
# Out:
# (15232, 129)

# %%
# Concatenating 'Age', 'Sex', 'Date'
df2[['Age', 'Sex', 'Date']] = df.loc[df2.index,['Age', 'Sex', 'Date']]
df2.head()
# Out:
#      Age     Sex       Date  2020-03-09 00:00:00  2020-03-10 00:00:00  \
# Case
# 1     41    Male 2020-03-09                  NaN                  NaN
# 2      0  Female 2020-03-10                  NaN                  NaN
# 3     13  Female 2020-03-10                  NaN                  NaN
# 4      0     NaN 2020-03-09                  NaN                  NaN
# 5     26    Male 2020-03-13                  NaN                  NaN
#
#       2020-03-11 00:00:00  2020-03-12 00:00:00  2020-03-13 00:00:00  \
# Case
# 1                     NaN                  NaN                  NaN
# 2                     NaN                  NaN                  NaN
# 3                     NaN                  NaN                  NaN
# 4                     NaN                  NaN                  NaN
# 5                     NaN                  NaN                  NaN
#
#       2020-03-14 00:00:00  2020-03-15 00:00:00  ...  2020-07-03 00:00:00  \
# ...

# %%
temp.index = df2['Date']
temp
# Out:
# Date
# 2020-03-09   2020-03-27
# 2020-03-10   2020-03-24
# 2020-03-10   2020-03-27
# 2020-03-09   2020-03-24
# 2020-03-13   2020-03-20
#                 ...
# 2020-07-11   2020-07-12
# 2020-07-11   2020-07-12
# 2020-07-11   2020-07-12
# 2020-07-11   2020-07-12
# 2020-07-11   2020-07-12
# Length: 15232, dtype: datetime64[ns]

# %%
cured = pd.DataFrame()
cured['Hospitalised time'] = temp - temp.index
cured.head()
# Out:
#            Hospitalised time
# Date
# 2020-03-09           18 days
# 2020-03-10           14 days
# 2020-03-10           17 days
# 2020-03-09           15 days
# 2020-03-13            7 days

# %%
cured.reset_index(inplace=True)
cured.index = df2.index
cured[['Age', 'Sex']] = df.loc[df2.index,['Age', 'Sex']]
cured.head()
# Out:
#            Date Hospitalised time Age     Sex
# Case
# 1    2020-03-09           18 days  41    Male
# 2    2020-03-10           14 days   0  Female
# 3    2020-03-10           17 days  13  Female
# 4    2020-03-09           15 days   0     NaN
# 5    2020-03-13            7 days  26    Male

# %%
del df2

# %% [markdown]
# # Deceased

# %%
df3 = df.isin(['D']).copy()

df3 = df3[df3==True]
df3.dropna(axis=0,how='all', inplace=True)
temp = df3.idxmax(axis=1)

# %%
df3.head()
# Out:
#       Age  Sex  Date  2020-03-09 00:00:00  2020-03-10 00:00:00  \
# Case
# 6     NaN  NaN   NaN                  NaN                  NaN
# 53    NaN  NaN   NaN                  NaN                  NaN
# 60    NaN  NaN   NaN                  NaN                  NaN
# 125   NaN  NaN   NaN                  NaN                  NaN
# 166   NaN  NaN   NaN                  NaN                  NaN
#
#       2020-03-11 00:00:00  2020-03-12 00:00:00  2020-03-13 00:00:00  \
# Case
# 6                     NaN                  NaN                  1.0
# 53                    NaN                  NaN                  NaN
# 60                    NaN                  NaN                  NaN
# 125                   NaN                  NaN                  NaN
# 166                   NaN                  NaN                  NaN
#
#       2020-03-14 00:00:00  2020-03-15 00:00:00  ...  2020-07-03 00:00:00  \
# Case                                            ...
# ...

# %%
df3.shape
# Out:
# (659, 129)

# %%
# Concatenating 'Age', 'Sex', 'Date'
df3[['Age', 'Sex', 'Date']] = df.loc[df3.index,['Age', 'Sex', 'Date']]
df3.head()
# Out:
#      Age     Sex       Date  2020-03-09 00:00:00  2020-03-10 00:00:00  \
# Case
# 6     76    Male 2020-03-12                  NaN                  NaN
# 53    70  Female 2020-03-26                  NaN                  NaN
# 60    60    Male 2020-03-27                  NaN                  NaN
# 125   75    Male 2020-04-03                  NaN                  NaN
# 166   80  Female 2020-04-07                  NaN                  NaN
#
#       2020-03-11 00:00:00  2020-03-12 00:00:00  2020-03-13 00:00:00  \
# Case
# 6                     NaN                  NaN                  1.0
# 53                    NaN                  NaN                  NaN
# 60                    NaN                  NaN                  NaN
# 125                   NaN                  NaN                  NaN
# 166                   NaN                  NaN                  NaN
#
#       2020-03-14 00:00:00  2020-03-15 00:00:00  ...  2020-07-03 00:00:00  \
# ...

# %%
temp.index = df3['Date']
temp
# Out:
# Date
# 2020-03-12   2020-03-13
# 2020-03-26   2020-03-26
# 2020-03-27   2020-03-27
# 2020-04-03   2020-04-04
# 2020-04-07   2020-04-16
#                 ...
# 2020-07-12   2020-07-12
# 2020-07-12   2020-07-12
# 2020-07-12   2020-07-12
# 2020-07-12   2020-07-12
# 2020-07-12   2020-07-12
# Length: 659, dtype: datetime64[ns]

# %%
deceased = pd.DataFrame()
deceased['Hospitalised time'] = temp - temp.index
deceased.head()
# Out:
#            Hospitalised time
# Date
# 2020-03-12            1 days
# 2020-03-26            0 days
# 2020-03-27            0 days
# 2020-04-03            1 days
# 2020-04-07            9 days

# %%
deceased.reset_index(inplace=True)
deceased.index = df3.index
deceased[['Age', 'Sex']] = df.loc[df3.index,['Age', 'Sex']]
deceased.head()
# Out:
#            Date Hospitalised time Age     Sex
# Case
# 6    2020-03-12            1 days  76    Male
# 53   2020-03-26            0 days  70  Female
# 60   2020-03-27            0 days  60    Male
# 125  2020-04-03            1 days  75    Male
# 166  2020-04-07            9 days  80  Female

# %%
del df3

# %% [markdown]
# # Debug
#
# Since some rows have "C" and "D" status

# %%
deceased.shape, cured.shape
# Out:
# ((659, 4), (15232, 4))

# %%
arr = deceased.index.isin(cured.index).copy()

len(arr)
# Out:
# 659

# %%
for i in range(len(arr)):
    if (arr[i]==False): continue
    print(i)
# Out:
# 1
# 227

# %%
deceased.index[1], deceased.index[227]
# Out:
# (53, 11382)

# %%
arr = cured.index.isin(deceased.index).copy()

len(arr)


for i in range(len(arr)):
    if (arr[i]==False): continue
    print(i)
# Out:
# 51
# 10212

# %%
cured.index[51], cured.index[10212]
# Out:
# (53, 11382)

# %% [markdown]
# ## These are the two cases with issues in them
